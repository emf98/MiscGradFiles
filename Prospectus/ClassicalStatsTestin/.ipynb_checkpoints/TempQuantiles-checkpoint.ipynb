# %%
import numpy as np
import math
import xarray as xr 
import pickle 
import matplotlib 
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

from sklearn.linear_model import LinearRegression
import scipy.stats

# %%
infile = open("./1979ERAdata/gph_97.p", 'rb')
gph = pickle.load(infile)
infile.close()

infile = open("./1979ERAdata/gph_time_97.p", 'rb')
gph_time = pickle.load(infile)
infile.close()

infile = open("./1979ERAdata/temp850_97.p", 'rb')
temp = pickle.load(infile)
infile.close()

infile = open("./1979ERAdata/temp850_time_97.p", 'rb')
temp_time = pickle.load(infile)
infile.close()

infile = open("./1979ERAdata/gph_time_97.p", 'rb')
gph_time = pickle.load(infile)
infile.close()

infile = open("./1979ERAdata/gph_lat_97.p", 'rb')
gph_lat = pickle.load(infile)
infile.close()

infile = open("./1979ERAdata/gph_lon_97.p", 'rb')
gph_lon = pickle.load(infile)
infile.close()

# %%
infile = open("../Clusters/Fall2023Clustering/UW_lat.p", 'rb')
unweighted_lat = pickle.load(infile)
infile.close()

infile = open("../Clusters/Fall2023Clustering/UW_lon.p", 'rb') 
unweighted_lon = pickle.load(infile)
infile.close()

# %%
#old root is ../../Ellipse_ERAI_data/
infile = open("../New_EllipseVals/ephi10_79.p", 'rb')
ephi10 = pickle.load(infile)
infile.close()

infile = open("../New_EllipseVals/ephi_ratio10_79.p", 'rb')
rat10 = pickle.load(infile)
infile.close()

infile = open("../New_EllipseVals/ephi_size10_79.p", 'rb')
size10 = pickle.load(infile)
infile.close()

infile = open("../New_EllipseVals/ephi_cenlat10_79.p", 'rb')
cenlat10 = pickle.load(infile)
infile.close()

infile = open("../New_EllipseVals/ephi_cenlon10_79.p", 'rb')
cenlon10 = pickle.load(infile)
infile.close()

infile = open("../New_EllipseVals/ephi_wind10_79.p", 'rb')
wind10 = pickle.load(infile)
infile.close()

# %%
infile = open("../EOFs/ehf100_latavg.p", 'rb')
ehf = pickle.load(infile)
infile.close()

ehf = ehf.reshape((40,608))

# %%
gph = xr.DataArray(data= gph, 
                       dims = ["time","lat","lon"],
                       coords = dict(
                           time = gph_time,
                           lat = unweighted_lat,
                           lon = unweighted_lon)
                      )
gph_D = gph.groupby('time.date').mean()

gph
# Out:
# <xarray.DataArray (time: 24320, lat: 128, lon: 512)>
# array([[[30898.127, 30898.383, 30899.045, ..., 30899.605, 30898.791,
#          30898.28 ],
#         [30898.434, 30898.791, 30899.504, ..., 30899.76 , 30898.893,
#          30898.434],
#         [30898.484, 30899.146, 30899.912, ..., 30899.504, 30898.586,
#          30898.28 ],
#         ...,
#         [29642.959, 29642.092, 29641.174, ..., 29645.764, 29644.846,
#          29643.877],
#         [29671.715, 29671.104, 29670.49 , ..., 29673.602, 29672.938,
#          29672.326],
#         [29701.693, 29701.389, 29701.133, ..., 29702.56 , 29702.256,
#          29701.95 ]],
#
#        [[30859.053, 30856.707, 30854.465, ..., 30865.223, 30863.438,
#          30861.348],
#         [30855.79 , 30853.445, 30851.303, ..., 30863.133, 30861.092,
#          30858.441],
#         [30853.037, 30850.793, 30848.906, ..., 30860.889, 30858.695,
#          30855.842],
# ...
#         [29473.12 , 29473.68 , 29474.24 , ..., 29471.588, 29472.098,
# ...

# %%
#calculate daily mean values
daily_mean_gph = gph.groupby('time.dayofyear').mean()
#test gph anomaly
daily_anom_gph = gph.groupby('time.dayofyear') - daily_mean_gph

##straight gph cap values
g_cap = gph.sel(lat = slice(60,90))

#anomaly cap values
cap_mean_gph = g_cap.groupby('time.dayofyear').mean()
#test gph anomaly
cap_anom_gph = g_cap.groupby('time.dayofyear') - cap_mean_gph
cap_anom_gph
# Out:
# <xarray.DataArray (time: 24320, lat: 42, lon: 512)>
# array([[[-174.88086 , -165.70508 , -156.59375 , ..., -202.39648 ,
#          -193.33008 , -184.20508 ],
#         [-184.66797 , -175.0625  , -165.5293  , ..., -212.70508 ,
#          -203.48633 , -194.19531 ],
#         [-191.7168  , -181.6582  , -171.60352 , ..., -220.43945 ,
#          -210.9414  , -201.48633 ],
#         ...,
#         [ 316.20312 ,  315.67383 ,  315.08008 , ...,  317.99023 ,
#           317.4121  ,  316.7832  ],
#         [ 338.03906 ,  337.64844 ,  337.24805 , ...,  339.23828 ,
#           338.79883 ,  338.4121  ],
#         [ 358.73047 ,  358.51953 ,  358.35938 , ...,  359.2832  ,
#           359.07812 ,  358.875   ]],
#
#        [[-226.49805 , -213.3457  , -200.25586 , ..., -263.1914  ,
#          -251.72852 , -239.49414 ],
#         [-232.15625 , -219.13281 , -206.08203 , ..., -268.60547 ,
#          -257.0918  , -244.89453 ],
#         [-236.39844 , -223.79102 , -211.1875  , ..., -272.00586 ,
# ...

# %%
g1 = np.nanmean(cap_anom_gph.values,axis=1)
ga = np.nanmean(g1 ,axis=1)
ga = ga.reshape((40,608))

# %%
temp = xr.DataArray(data= temp, 
                       dims = ["time","lat","lon"],
                       coords = dict(
                           time = temp_time,
                           lat = unweighted_lat,
                           lon = unweighted_lon)
                      )
temp_D = temp.groupby('time.date').mean()

temp
# Out:
# <xarray.DataArray (time: 24320, lat: 128, lon: 512)>
# array([[[289.2945 , 289.357  , 289.2652 , ..., 289.15973, 289.19293,
#          289.14215],
#         [289.59625, 289.68903, 289.58258, ..., 289.41754, 289.50153,
#          289.45758],
#         [289.64996, 289.6939 , 289.67535, ..., 289.72418, 289.7447 ,
#          289.6734 ],
#         ...,
#         [253.96733, 253.97514, 253.98198, ..., 253.93999, 253.94975,
#          253.95854],
#         [253.44292, 253.4439 , 253.44292, ..., 253.43999, 253.44194,
#          253.44292],
#         [252.87163, 252.87163, 252.87163, ..., 252.87163, 252.87163,
#          252.87163]],
#
#        [[288.95602, 288.99802, 289.00778, ..., 288.91208, 288.93063,
#          288.87888],
#         [289.29977, 289.36325, 289.40915, ..., 289.22946, 289.26755,
#          289.21872],
#         [289.54   , 289.59372, 289.62497, ..., 289.48532, 289.39645,
#          289.38864],
# ...
#         [260.26007, 260.35773, 260.45538, ..., 259.96906, 260.0667 ,
# ...

# %%
#calculate daily mean values
daily_mean_temp = temp.groupby('time.dayofyear').mean()
#test gph anomaly
daily_anom_temp = temp.groupby('time.dayofyear') - daily_mean_temp

##straight cap values
t_cap = temp.sel(lat = slice(60,90))
##great lakes
t_gl = temp.sel(lat = slice(40,50), lon = slice(270,290))

#anomaly cap values
cap_mean_t= t_cap.groupby('time.dayofyear').mean()
#test gph anomaly
cap_anom_t = t_cap.groupby('time.dayofyear') - cap_mean_t

#anomaly cap values
gl_mean_t= t_gl.groupby('time.dayofyear').mean()
#test gph anomaly
gl_anom_t = t_gl.groupby('time.dayofyear') - gl_mean_t
#gl_anom_t

# %%
t2 = np.nanmean(gl_anom_t.values,axis=1)
tg = np.nanmean(t2 ,axis=1)
tg = tg.reshape((40,608))

# %%
ephi10 = np.delete(ephi10,[480,481,482,483,605,606,607],1)
rat10 = np.delete(rat10,[480,481,482,483,605,606,607],1)
size10 = np.delete(size10,[480,481,482,483,605,606,607],1)
cenlat10 = np.delete(cenlat10,[480,481,482,483,605,606,607],1)
cenlon10 = np.delete(cenlon10,[480,481,482,483,605,606,607],1)
wind10 = np.delete(wind10,[480,481,482,483,605,606,607],1)
tp = np.delete(tg,[480,481,482,483,605,606,607],1)
gp = np.delete(ga,[480,481,482,483,605,606,607],1)
eh = np.delete(ehf,[480,481,482,483,605,606,607],1)

# %%
t = tp.reshape((24040,))
g = gp.reshape((24040,))
ef = eh.reshape((24040,)) 
wind = np.reshape(wind10, (24040))
ephi = np.reshape(ephi10, (24040))
rat = np.reshape(rat10, (24040))
size = np.reshape(size10, (24040))
cenlt= np.reshape(cenlat10, (24040))
cenln= np.reshape(cenlon10, (24040))

# %%
##quantiles of anomalies !! 
mx = np.nanquantile(t,1,axis = 0) #maximum
q90 = np.nanquantile(t,0.9,axis = 0) #ninety
q85 = np.nanquantile(t,0.85,axis = 0)
q80 = np.nanquantile(t,0.8,axis = 0)
q75 = np.nanquantile(t,0.75,axis = 0) #seventy
q70 = np.nanquantile(t,0.7,axis = 0)
q65 = np.nanquantile(t,0.65,axis = 0)
q60 = np.nanquantile(t,0.6,axis = 0) 
q55 = np.nanquantile(t,0.55,axis = 0)
q50 = np.nanquantile(t,0.5,axis = 0) 
q45 = np.nanquantile(t,0.45,axis = 0)
q40 = np.nanquantile(t,0.4,axis = 0)
q35 = np.nanquantile(t,0.35,axis = 0)
q30 = np.nanquantile(t,0.3,axis = 0) #thirty 
q25 = np.nanquantile(t,0.25,axis = 0)
q20 = np.nanquantile(t,0.2,axis = 0)
q15 = np.nanquantile(t,0.15,axis = 0)
q10 = np.nanquantile(t,0.1,axis = 0) 
mn = np.nanquantile(t,0,axis = 0) #minimum

# %%
#set empty list of metrics across clusters
w_mn = []
e_mn = []
r_mn = []
s_mn = []
ct_mn = []
cn_mn = []
g_mn = []
eh_mn = []

w1 = []
e1 = []
r1 = []
s1 = []
ct1 = []
cn1 = []
g1 = []
eh1 = []

w3 = []
e3 = []
r3 = []
s3 = []
ct3 = []
cn3 = []
g3 = []
eh3 = []

w5 = []
e5 = []
r5 = []
s5 = []
ct5 = []
cn5 = []
g5 = []
eh5 = []

w6 = []
e6 = []
r6 = []
s6 = []
ct6 = []
cn6 = []
g6 = []
eh6 = []

w7 = []
e7 = []
r7 = []
s7 = []
ct7 = []
cn7 = []
g7 = []
eh7 = []

w_mx = []
e_mx = []
r_mx = []
s_mx = []
ct_mx = []
cn_mx = []
g_mx = []
eh_mx = []

# %%
#####fix this tn, also make box plots tn

# %%
for i in range(len(tp[:,0])):
    for j in range(56,601,1):
        if tp[i,j] >= mn and tp[i,j] < q10:
            if tp[i,j-56:j-12].all() >= mn and tp[i,j-56:j-12].all() < q10:
                continue
            else: 
                #print(label[i,j])
                w_mn.append(wind10[i,j-56:j])
                e_mn.append(ephi10[i,j-56:j])
                s_mn.append(size10[i,j-56:j])
                r_mn.append(rat10[i,j-56:j])
                ct_mn.append(cenlat10[i,j-56:j])
                cn_mn.append(cenlon10[i,j-56:j])
                g_mn.append(gp[i,j-56:j])
                eh_mn.append(eh[i,j-56:j])
                
        if tp[i,j] >= q10 and tp[i,j] < q25:
            if tp[i,j-56:j-12].all() >= q10 and tp[i,j-56:j-12].all() < q25:
                continue
            else: 
                #print(label[i,j])
                w1.append(wind10[i,j-56:j])
                e1.append(ephi10[i,j-56:j])
                s1.append(size10[i,j-56:j])
                r1.append(rat10[i,j-56:j])
                ct1.append(cenlat10[i,j-56:j])
                cn1.append(cenlon10[i,j-56:j])
                g1.append(gp[i,j-56:j])
                eh1.append(eh[i,j-56:j])
                
        if tp[i,j] >= q25 and tp[i,j] < q40:
            if tp[i,j-56:j-12].all() >= q25 and tp[i,j-56:j-12].all() < q40:
                continue
            else: 
                #print(label[i,j])
                w3.append(wind10[i,j-56:j])
                e3.append(ephi10[i,j-56:j])
                s3.append(size10[i,j-56:j])
                r3.append(rat10[i,j-56:j])
                ct3.append(cenlat10[i,j-56:j])
                cn3.append(cenlon10[i,j-56:j])
                g3.append(gp[i,j-56:j])
                eh3.append(eh[i,j-56:j])
                
        if tp[i,j] >= q40 and tp[i,j] < q60:
            #print(label[i,j])
            w5.append(wind10[i,j-56:j])
            e5.append(ephi10[i,j-56:j])
            s5.append(size10[i,j-56:j])
            r5.append(rat10[i,j-56:j])
            ct5.append(cenlat10[i,j-56:j])
            cn5.append(cenlon10[i,j-56:j])
            g5.append(gp[i,j-56:j])
            eh5.append(eh[i,j-56:j])
                
        if tp[i,j] >= q60 and tp[i,j] < q75:
            if tp[i,j-56:j-12].all() >= q60 and pt[i,j-56:j-12].all() < q75:
                continue
            else: 
                #print(label[i,j])
                w6.append(wind10[i,j-56:j])
                e6.append(ephi10[i,j-56:j])
                s6.append(size10[i,j-56:j])
                r6.append(rat10[i,j-56:j])
                ct6.append(cenlat10[i,j-56:j])
                cn6.append(cenlon10[i,j-56:j])
                g6.append(gp[i,j-56:j])
                eh6.append(eh[i,j-56:j])
                
        if tp[i,j] >= q75 and tp[i,j] < q90:
            if tp[i,j-56:j-12].all() >= q75 and tp[i,j-56:j-12].all() < q90:
                continue
            else: 
                #print(label[i,j])
                w7.append(wind10[i,j-56:j])
                e7.append(ephi10[i,j-56:j])
                s7.append(size10[i,j-56:j])
                r7.append(rat10[i,j-56:j])
                ct7.append(cenlat10[i,j-56:j])
                cn7.append(cenlon10[i,j-56:j])
                g7.append(gp[i,j-56:j])
                eh7.append(eh[i,j-56:j])
    
        if tp[i,j] >= q90 and tp[i,j] <= mx:
            if tp[i,j-56:j-12].all() >= q90 and tp[i,j-56:j-12].all() < mx:
                continue
            else: 
                #print(label[i,j])
                w_mx.append(wind10[i,j-56:j])
                e_mx.append(ephi10[i,j-56:j])
                s_mx.append(size10[i,j-56:j])
                r_mx.append(rat10[i,j-56:j])
                ct_mx.append(cenlat10[i,j-56:j])
                cn_mx.append(cenlon10[i,j-56:j])
                g_mx.append(gp[i,j-56:j])
                eh_mx.append(eh[i,j-56:j])

# %%
wind_clus = np.empty((7,56))
ephi_clus = np.empty((7,56))
size_clus = np.empty((7,56))
rat_clus = np.empty((7,56))
cenlat_clus = np.empty((7,56))
cenlon_clus = np.empty((7,56))
gph_clus = np.empty((7,56))
ehf_clus = np.empty((7,56))

# %%
wind_clus[0,:] = np.nanmean(np.array(w_mn), axis = 0)
wind_clus[1,:] = np.nanmean(np.array(w1), axis = 0)
wind_clus[2,:] = np.nanmean(np.array(w3), axis = 0)
wind_clus[3,:] = np.nanmean(np.array(w5), axis = 0)
wind_clus[4,:] = np.nanmean(np.array(w6), axis = 0)
wind_clus[5,:] = np.nanmean(np.array(w7), axis = 0)
wind_clus[6,:] = np.nanmean(np.array(w_mx), axis = 0)

ephi_clus[0,:] = np.nanmean(np.array(e_mn), axis = 0)
ephi_clus[1,:] = np.nanmean(np.array(e1), axis = 0)
ephi_clus[2,:] = np.nanmean(np.array(e3), axis = 0)
ephi_clus[3,:] = np.nanmean(np.array(e5), axis = 0)
ephi_clus[4,:] = np.nanmean(np.array(e6), axis = 0)
ephi_clus[5,:] = np.nanmean(np.array(e7), axis = 0)
ephi_clus[6,:] = np.nanmean(np.array(e_mx), axis = 0)

size_clus[0,:] = np.nanmean(np.array(s_mn), axis = 0)
size_clus[1,:] = np.nanmean(np.array(s1), axis = 0)
size_clus[2,:] = np.nanmean(np.array(s3), axis = 0)
size_clus[3,:] = np.nanmean(np.array(s5), axis = 0)
size_clus[4,:] = np.nanmean(np.array(s6), axis = 0)
size_clus[5,:] = np.nanmean(np.array(s7), axis = 0)
size_clus[6,:] = np.nanmean(np.array(s_mx), axis = 0)

rat_clus[0,:] = np.nanmean(np.array(r_mn), axis = 0)
rat_clus[1,:] = np.nanmean(np.array(r1), axis = 0)
rat_clus[2,:] = np.nanmean(np.array(r3), axis = 0)
rat_clus[3,:] = np.nanmean(np.array(r5), axis = 0)
rat_clus[4,:] = np.nanmean(np.array(r6), axis = 0)
rat_clus[5,:] = np.nanmean(np.array(r7), axis = 0)
rat_clus[6,:] = np.nanmean(np.array(r_mx), axis = 0)

cenlat_clus[0,:] = np.nanmean(np.array(ct_mn), axis = 0)
cenlat_clus[1,:] = np.nanmean(np.array(ct1), axis = 0)
cenlat_clus[2,:] = np.nanmean(np.array(ct3), axis = 0)
cenlat_clus[3,:] = np.nanmean(np.array(ct5), axis = 0)
cenlat_clus[4,:] = np.nanmean(np.array(ct6), axis = 0)
cenlat_clus[5,:] = np.nanmean(np.array(ct7), axis = 0)
cenlat_clus[6,:] = np.nanmean(np.array(ct_mx), axis = 0)

cenlon_clus[0,:] = np.nanmean(np.array(cn_mn), axis = 0)
cenlon_clus[1,:] = np.nanmean(np.array(cn1), axis = 0)
cenlon_clus[2,:] = np.nanmean(np.array(cn3), axis = 0)
cenlon_clus[3,:] = np.nanmean(np.array(cn5), axis = 0)
cenlon_clus[4,:] = np.nanmean(np.array(cn6), axis = 0)
cenlon_clus[5,:] = np.nanmean(np.array(cn7), axis = 0)
cenlon_clus[6,:] = np.nanmean(np.array(cn_mx), axis = 0)

gph_clus[0,:] = np.nanmean(np.array(g_mn), axis = 0)
gph_clus[1,:] = np.nanmean(np.array(g1), axis = 0)
gph_clus[2,:] = np.nanmean(np.array(g3), axis = 0)
gph_clus[3,:] = np.nanmean(np.array(g5), axis = 0)
gph_clus[4,:] = np.nanmean(np.array(g6), axis = 0)
gph_clus[5,:] = np.nanmean(np.array(g7), axis = 0)
gph_clus[6,:] = np.nanmean(np.array(g_mx), axis = 0)

ehf_clus[0,:] = np.nanmean(np.array(eh_mn), axis = 0)
ehf_clus[1,:] = np.nanmean(np.array(eh1), axis = 0)
ehf_clus[2,:] = np.nanmean(np.array(eh3), axis = 0)
ehf_clus[3,:] = np.nanmean(np.array(eh5), axis = 0)
ehf_clus[4,:] = np.nanmean(np.array(eh6), axis = 0)
ehf_clus[5,:] = np.nanmean(np.array(eh7), axis = 0)
ehf_clus[6,:] = np.nanmean(np.array(eh_mx), axis = 0)

# %%
#forecast_days = [i for i in range(-14,0,1)]
forecast_days = [i for i in range(-56,0,1)]

# %%
colors = ['red','orange','green','cyan','blue','violet','magenta']
quant = ['0-10', '10-25', '25-40', '40-60', '60-75', '75-90', '90-100']

# %%
# %matplotlib inline
##big plots
myLocator = mticker.MultipleLocator(4)

fig = plt.figure(figsize=(18,12),dpi=150)
fig.suptitle("Mean Hourly Elliptical Metric Values for Days 0-14 Prior to Temperature Quantile") 

#loop through each member
ax1 = plt.subplot(4,2,1)
ax2 = plt.subplot(4,2,2)
ax3 = plt.subplot(4,2,3)
ax4 = plt.subplot(4,2,4)
ax5 = plt.subplot(4,2,5)
ax6 = plt.subplot(4,2,6)
ax7 = plt.subplot(4,2,7)
ax8 = plt.subplot(4,2,8)

for m in range(0,7,1):
    #print(u_data_mem)
    # Specify how our lines should look
    #colorR = (m+2)/ 15.
    ax1.plot(forecast_days, wind_clus[m,:], color=colors[m], label='Quantile '+quant[m])
    ax1.set_xlabel('Timestep Prior',fontsize = 12)
    ax1.set_ylabel('Zonal Mean Zonal Wind (m/s)',fontsize = 12)
    ax1.tick_params(axis='both', which='major', labelsize=10)
    ax1.legend(loc='lower left',fontsize='medium');
    
    ax2.plot(forecast_days, rat_clus[m,:], color=colors[m], label='Quantile '+quant[m])
    ax2.set_xlabel('Timestep Prior', fontsize = 12)
    ax2.set_ylabel('Ratio (m)', fontsize = 12)
    ax2.tick_params(axis='both', which='major', labelsize=10)
    ax2.legend(loc='lower left',fontsize='medium');
    
    ax3.plot(forecast_days, ephi_clus[m,:], color=colors[m], label='Quantile '+quant[m])
    ax3.set_xlabel('Timestep Prior', fontsize = 12)
    ax3.set_ylabel('Rotation Angle ($^o$)', fontsize = 12)
    ax3.tick_params(axis='both', which='major', labelsize=10)
    ax3.legend(loc='lower left',fontsize='medium');
    
    ax4.plot(forecast_days, size_clus[m,:], color=colors[m], label='Quantile '+quant[m])
    ax4.set_xlabel('Timestep Prior', fontsize = 12)
    ax4.set_ylabel('Ellipse Area (m$^2$)', fontsize = 12)
    ax4.tick_params(axis='both', which='major', labelsize=10)
    ax4.legend(loc='lower left',fontsize='medium');
    
    ax5.plot(forecast_days, cenlat_clus[m,:], color=colors[m], label='Quantile '+quant[m])
    ax5.set_xlabel('Timestep Prior', fontsize = 12)
    ax5.set_ylabel('Latitude ($^o$)', fontsize = 12)
    ax5.tick_params(axis='both', which='major', labelsize=10)
    ax5.legend(loc='lower left',fontsize='medium');
    
    ax6.plot(forecast_days, cenlon_clus[m,:], color=colors[m], label='Quantile '+quant[m])
    ax6.set_xlabel('Timestep Prior', fontsize = 12)
    ax6.set_ylabel('Longitude ($^o$)', fontsize = 12)
    ax6.tick_params(axis='both', which='major', labelsize=10)
    ax6.legend(loc='lower left',fontsize='medium');
    
    ax7.plot(forecast_days, gph_clus[m,:], color=colors[m], label='Quantile '+quant[m])
    ax7.set_xlabel('Timestep Prior', fontsize = 12)
    ax7.set_ylabel('GPH Anomaly (m)', fontsize = 12)
    ax7.tick_params(axis='both', which='major', labelsize=10)
    ax7.legend(loc='lower left',fontsize='medium');
    
    ax8.plot(forecast_days, ehf_clus[m,:], color=colors[m], label='Quantile '+quant[m])
    ax8.set_xlabel('Timestep Prior', fontsize = 12)
    ax8.set_ylabel('Eddy Heat Flux (Kg/ms$^2$)', fontsize = 12)
    ax8.tick_params(axis='both', which='major', labelsize=10)
    ax8.legend(loc='lower left',fontsize='medium');

plt.tight_layout()
plt.show()
fig.savefig("Mean_HOURLY_DaysToQuant.png")

# %%
################## FOR BOX PLOTS ##################

# %%
cenlt10 = np.nan_to_num(cenlat10, nan = -999)
cenln10 = np.nan_to_num(cenlon10, nan = -999)
rat10 = np.nan_to_num(rat10, nan = -999)
size10 = np.nan_to_num(size10, nan = -999)
ephi10 = np.nan_to_num(ephi10, nan = -999)
wind10 = np.nan_to_num(wind10, nan = -999)

# %%
#set empty list of metrics across clusters
w1 = []
e1 = []
r1 = []
s1 = []
ct1 = []
cn1 = []

w2 = []
e2 = []
r2 = []
s2 = []
ct2 = []
cn2 = []

w3 = []
e3 = []
r3 = []
s3 = []
ct3 = []
cn3 = []

w4 = []
e4 = []
r4 = []
s4 = []
ct4 = []
cn4 = []

w5 = []
e5 = []
r5 = []
s5 = []
ct5 = []
cn5 = []

w6 = []
e6 = []
r6 = []
s6 = []
ct6 = []
cn6 = []

w7 = []
e7 = []
r7 = []
s7 = []
ct7 = []
cn7 = []

# %%
for i in range(len(tp)):
    for j in range(56,601,1):
        if tp[i,j] >= mn and tp[i,j] < q10:
            if tp[i,j-56:j-12].all() >= mn and tp[i,j-56:j-12].all() < q10:
                continue
            else: 
                #print(label[i,j])
                w1.append(wind10[i,j-56])
                e1.append(ephi10[i,j-56])
                s1.append(size10[i,j-56])
                r1.append(rat10[i,j-56])
                ct1.append(cenlat10[i,j-56])
                cn1.append(cenlon10[i,j-56])
                
        if tp[i,j] >= q10 and tp[i,j] < q25:
            if tp[i,j-56:j-12].all() >= q10 and tp[i,j-56:j-12].all() < q25:
                continue
            else: 
                #print(label[i,j])
                w2.append(wind10[i,j-56])
                e2.append(ephi10[i,j-56])
                s2.append(size10[i,j-56])
                r2.append(rat10[i,j-56])
                ct2.append(cenlat10[i,j-56])
                cn2.append(cenlon10[i,j-56])
                
        if tp[i,j] >= q25 and tp[i,j] < q40:
            if tp[i,j-56:j-12].all() >= q25 and tp[i,j-56:j-12].all() < q40:
                continue
            else: 
                #print(label[i,j])
                w3.append(wind10[i,j-56])
                e3.append(ephi10[i,j-56])
                s3.append(size10[i,j-56])
                r3.append(rat10[i,j-56])
                ct3.append(cenlat10[i,j-56])
                cn3.append(cenlon10[i,j-56])
            
        if tp[i,j] >= q40 and tp[i,j] < q60:
            #print(label[i,j])
            w4.append(wind10[i,j-56])
            e4.append(ephi10[i,j-56])
            s4.append(size10[i,j-56])
            r4.append(rat10[i,j-56])
            ct4.append(cenlat10[i,j-56])
            cn4.append(cenlon10[i,j-56])
                
        if tp[i,j] >= q60 and tp[i,j] < q75:
            if tp[i,j-56:j-12].all() >= q60 and pt[i,j-56:j-12].all() < q75:
                continue
            else: 
                #print(label[i,j])
                w5.append(wind10[i,j-56])
                e5.append(ephi10[i,j-56])
                s5.append(size10[i,j-56])
                r5.append(rat10[i,j-56])
                ct5.append(cenlat10[i,j-56])
                cn5.append(cenlon10[i,j-56])
                
        if tp[i,j] >= q75 and tp[i,j] < q90:
            if tp[i,j-56:j-12].all() >= q75 and tp[i,j-56:j-12].all() < q90:
                continue
            else: 
                #print(label[i,j])
                w6.append(wind10[i,j-56])
                e6.append(ephi10[i,j-56])
                s6.append(size10[i,j-56])
                r6.append(rat10[i,j-56])
                ct6.append(cenlat10[i,j-56])
                cn6.append(cenlon10[i,j-56])
    
        if tp[i,j] >= q90 and tp[i,j] <= mx:
            if tp[i,j-56:j-12].all() >= q90 and tp[i,j-56:j-12].all() < mx:
                continue
            else: 
                #print(label[i,j])
                w7.append(wind10[i,j-56])
                e7.append(ephi10[i,j-56])
                s7.append(size10[i,j-56])
                r7.append(rat10[i,j-56])
                ct7.append(cenlat10[i,j-56])
                cn7.append(cenlon10[i,j-56])

# %%
#filter out to ignore NaNs.
##Wind
w1 = [i for i in w1 if i > -50]
w2 = [i for i in w2 if i > -50]
w3 = [i for i in w3 if i > -50]
w4 = [i for i in w4 if i > -50]
w5 = [i for i in w5 if i > -50]
w6 = [i for i in w6 if i > -50]
w7 = [i for i in w7 if i > -50]

##Ephi
e1 = [i for i in e1 if i > -200]
e2 = [i for i in e2 if i > -200]
e3 = [i for i in e3 if i > -200]
e4 = [i for i in e4 if i > -200]
e5 = [i for i in e5 if i > -200]
e6 = [i for i in e6 if i > -200]
e7 = [i for i in e7 if i > -200]

##Size
s1 = [i for i in s1 if i > -50]
s2 = [i for i in s2 if i > -50]
s3 = [i for i in s3 if i > -50]
s4 = [i for i in s4 if i > -50]
s5 = [i for i in s5 if i > -50]
s6 = [i for i in s6 if i > -50]
s7 = [i for i in s7 if i > -50]

##Ratio
r1 = [i for i in r1 if i > -50]
r2 = [i for i in r2 if i > -50]
r3 = [i for i in r3 if i > -50]
r4 = [i for i in r4 if i > -50]
r5 = [i for i in r5 if i > -50]
r6 = [i for i in r6 if i > -50]
r7 = [i for i in r7 if i > -50]

##Center Latitude
ct1 = [i for i in ct1 if i > -50]
ct2 = [i for i in ct2 if i > -50]
ct3 = [i for i in ct3 if i > -50]
ct4 = [i for i in ct4 if i > -50]
ct5 = [i for i in ct5 if i > -50]
ct6 = [i for i in ct6 if i > -50]
ct7 = [i for i in ct7 if i > -50]

##Center Longitude
cn1 = [i for i in cn1 if i > -360]
cn2 = [i for i in cn2 if i > -360]
cn3 = [i for i in cn3 if i > -360]
cn4 = [i for i in cn4 if i > -360]
cn5 = [i for i in cn5 if i > -360]
cn6 = [i for i in cn5 if i > -360]
cn7 = [i for i in cn5 if i > -360]

# %%
#lists of combined cluster data from different metrics

wind_clus = [w1,w2,w3,w4,w5,w6,w7]
ephi_clus = [e1,e2,e3,e4,e5,e6,e7]
rat_clus = [r1,r2,r3,r4,r5,r6,r7]
size_clus = [s1,s2,s3,s4,s5,s6,s7]
cenlat_clus = [ct1,ct2,ct3,ct4,ct5,ct6,ct7]
cenlon_clus = [cn1,cn2,cn3,cn4,cn5,cn6,cn7]

# %%
# %matplotlib inline
fig = plt.figure(figsize=(18,12),dpi=150)
fig.suptitle("Ranges of Elliptical Metrics 14th Day Prior to Temperature Quantile",fontsize = 20)
#loop through each member
ax1 = plt.subplot(2,3,1)
ax1.boxplot(wind_clus)
ax1.set_xlabel("Quantile",fontsize = 16)
ax1.set_ylabel("Zonal Mean Wind (m/s)",fontsize = 16)
ax1.tick_params(axis='both', which='major', labelsize=14)

ax2 = plt.subplot(2,3,2)
ax2.boxplot(ephi_clus)
ax2.set_xlabel("Quantile",fontsize = 16)
ax2.set_ylabel("Rotation Angle ($^o$)",fontsize = 16)
ax2.tick_params(axis='both', which='major', labelsize=14)

ax3 = plt.subplot(2,3,3)
ax3.boxplot(rat_clus)
ax3.set_xlabel("Quantile",fontsize = 16)
ax3.set_ylabel("Ratio (m)",fontsize = 16)
ax3.tick_params(axis='both', which='major', labelsize=14)

ax4 = plt.subplot(2,3,4)
ax4.boxplot(size_clus)
ax4.set_xlabel("Quantile",fontsize = 16)
ax4.set_ylabel("Elliptical Area (m$^2$)",fontsize = 16)
ax4.tick_params(axis='both', which='major', labelsize=14)

ax5 = plt.subplot(2,3,5)
ax5.boxplot(cenlat_clus)
ax5.set_xlabel("Quantile",fontsize = 16)
ax5.set_ylabel("Latitude ($^o$)",fontsize = 16)
ax5.tick_params(axis='both', which='major', labelsize=14)

ax6 = plt.subplot(2,3,6)
ax6.boxplot(cenlon_clus)
ax6.set_xlabel("Quantile",fontsize = 16)
ax6.set_ylabel("Longitude ($^o$)",fontsize = 16)
ax6.tick_params(axis='both', which='major', labelsize=14)

fig.tight_layout()
#fig.savefig("AnomalyClus_Met_BoxPlot.png")

# %% [markdown]
# #### Let us create the chicklet plot for temp quantiles, lol

# %%
label = []

for i in range(len(t)):
    if t[i] >= mn and t[i] < q10:
        label.append(1)
        
    if t[i] >= q10 and t[i] < q25:
        label.append(2)
        
    if t[i] >= q25 and t[i] < q40:
        label.append(3)
        
    if t[i] >= q40 and t[i] < q60:
        label.append(4)
        
    if t[i] >= q60 and t[i] < q75:
        label.append(5)
        
    if t[i] >= q75 and t[i] < q90:
        label.append(6)
    
    if t[i] >= q90 and t[i] <= mx:
        label.append(7)

label = np.reshape(label,(40,601))

# %%
label
# Out:
# array([[6, 6, 6, ..., 4, 4, 4],
#        [3, 2, 2, ..., 5, 6, 6],
#        [6, 6, 6, ..., 6, 5, 5],
#        ...,
#        [5, 6, 6, ..., 4, 5, 4],
#        [1, 1, 2, ..., 2, 2, 3],
#        [4, 4, 4, ..., 2, 2, 1]])

# %%
gph_array = gph["time"].to_numpy()
cluster_dates = gph_array.reshape(40,608)
quant_dates = np.delete(cluster_dates,[480,481,482,483,605,606,607],1)

# %%
import datetime as dt
import pandas as pd
days = []
years = []

for i in range(len(quant_dates[0,:])):
    test = quant_dates[0,i]
    t =  pd.to_datetime(str(test)) 
    test = t.strftime("%m-%d")
    days.append(test)

for i in range(len(quant_dates[:,0])):
    test = quant_dates[i,0]
    t =  pd.to_datetime(str(test)) 
    test = t.strftime("%Y")
    years.append(test)

# %%
quant_dates = xr.DataArray(data= label, 
                       dims = ["year","day"],
                       coords = dict(
                           year = years,
                           day = days)
                      )
quant_dates
# Out:
# <xarray.DataArray (year: 40, day: 601)>
# array([[6, 6, 6, ..., 4, 4, 4],
#        [3, 2, 2, ..., 5, 6, 6],
#        [6, 6, 6, ..., 6, 5, 5],
#        ...,
#        [5, 6, 6, ..., 4, 5, 4],
#        [1, 1, 2, ..., 2, 2, 3],
#        [4, 4, 4, ..., 2, 2, 1]])
# Coordinates:
#   * year     (year) <U4 '1979' '1980' '1981' '1982' ... '2016' '2017' '2018'
#   * day      (day) <U5 '11-01' '11-01' '11-01' ... '03-30' '03-30' '03-31'

# %%
pickle.dump(label, open("quant_labels.p", 'wb'))

# %%
# %matplotlib inline
myLocator = mticker.MultipleLocator(8)
fig, ax = plt.subplots(1, 1, figsize=(15, 15)) 
# define the bins and normalize
plt.title("Temperature Quantiles for 850hPa Anomalies over GL Region, 1979-2019",fontsize=18)
cmap = matplotlib.cm.jet
norm = matplotlib.colors.Normalize(vmin = np.min(quant_dates.values),
                                   vmax=np.max(quant_dates.values))

cax = ax.pcolormesh(quant_dates['day'].values,
              quant_dates['year'].values, 
              quant_dates.values,cmap=cmap, norm=norm)

ax.xaxis.set_major_locator(myLocator)
plt.xticks(rotation=60,fontsize = 14)
plt.xlabel("Day of Year",fontsize = 14)
plt.yticks(fontsize = 14)
plt.ylabel("Year",fontsize = 15)

cbar = fig.colorbar(cax, ticks=[7,6,5,4,3,2,1])
cbar.ax.set_yticklabels(['90-100', '75-90', '60-75', '40-60', '25-40', '10-25', '0-10']) 
cbar.set_label(label='Quantile', size=14)

cbar.update_ticks()

plt.savefig("TempAnomQuantbyDay.png")
# Out:
# /tmp/ipykernel_16202/1603956490.py:10: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   cax = ax.pcolormesh(quant_dates['day'].values,
