# %% [markdown]
# #### This code is formatted to use ERA-5/ERA-I data for calculating ellipses and metrics of the ellipse during a set period of record.
#
# In this code is an example for calculating and saving the ellipse metrics in a very brute-force manner.
#
# Below are the relevant import statements, including `fitEllipse3_new` and `EllipseDef`, which are an additional python files.

# %%
import datetime as dt
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import cartopy.feature
from cartopy.util import add_cyclic_point
import cartopy.crs as ccrs
import xarray as xr
import math
import netCDF4
#from get_ellipse_metrics import get_emetrics_max_min
from fitEllipse3_new import fitEllipseContour
from fitEllipse3_new import point_inside_polygon
#from EllipseCalc import ellipse_calc
from geopy.distance import great_circle
from matplotlib.patches import Polygon
from matplotlib import cm #colormaps!
import copy
import os
import scipy.stats
import pickle

#os.environ['DISPLAY']=':0.0'

# %% [markdown]
# This code requires you to **indicate save locations** for your images of ellipses and **import ERA-5 or ERA-Interim data**. This code assumes the user has the data saved locally.
#
# Please look at these definition statements to modify how the data is called for your circumstance.

# %%
from EllipseDef import ERA5_one_ellipse_calc
from EllipseDef import ERA5_two_ellipse_calc

from EllipseDef import ERAI_one_ellipse_calc
from EllipseDef import ERAI_two_ellipse_calc

# %% [markdown]
# The main part of the code begins here.

# %%
home_dir = '/home11/grad/2020/ef935217/Research/Dissertation/ELLIPSE_PAPER/' # Define your home working directory
lev_list = [10] #Define your list of hPa levels
temp_lev = [850] #Define your temperature level in hPa
#contour_list = [31500,20000,23000]
contour_list = [30000] #Define your list of contours relevant to hPa measures #20000 for 50
windlat = 60.0 #Define latitude for zonal-mean winds
#write_out = True #write the ellipse data to a text file, True or False

# %% [markdown]
# The next chunk of code may be relevant for defining empty arrays of elliptical metrics should you wish to export and use them.
#
# `43` refers to the number of years covered by the period of record (1979-2022) and `152` refers to the number of time indexes (daily, November through March).

# %%
ephi_ratio10 = np.empty((40,2,152))
ephi_ratio10[:] = np.nan
ephi_wind10 = np.empty((40,2,152))
ephi_wind10[:] = np.nan
ephi_cenlat10 = np.empty((40,2,152))
ephi_cenlat10[:] = np.nan
ephi_cenlon10 = np.empty((40,2,152))
ephi_cenlon10[:] = np.nan
ephi_size10 = np.empty((40,2,152))
ephi_size10[:] = np.nan
ephi10 = np.empty((40,2,152))
ephi10[:] = np.nan
number10 = np.empty((40,152))
number10[:] = np.nan


ephi_ratio50 = np.empty((43,2,152))
ephi_ratio50[:] = np.nan
ephi_wind50 = np.empty((43,2,152))
ephi_wind50[:] = np.nan
ephi_cenlat50 = np.empty((43,2,152))
ephi_cenlat50[:] = np.nan
ephi_cenlon50 = np.empty((43,2,152))
ephi_cenlon50[:] = np.nan
ephi_size50 = np.empty((43,2,152))
ephi_size50[:] = np.nan
number50 = np.empty((43,152))
number50[:] = np.nan

# %%
ephi_ratio10 = np.empty((21,2,152))
ephi_ratio10[:] = np.nan
ephi_wind10 = np.empty((21,2,152))
ephi_wind10[:] = np.nan
ephi_cenlat10 = np.empty((21,2,152))
ephi_cenlat10[:] = np.nan
ephi_cenlon10 = np.empty((21,2,152))
ephi_cenlon10[:] = np.nan
ephi_size10 = np.empty((21,2,152))
ephi_size10[:] = np.nan
ephi10 = np.empty((21,2,152))
ephi10[:] = np.nan
number10 = np.empty((21,152))
number10[:] = np.nan

# %% [markdown]
# These empty lists are where the data will be saved within the definition statements.

# %%
rat10 = []
wind10 = []
cenlat10 = []
cenlon10 = []
size10 = []
ep10 = []
numb10 =[]
    
rat50 = []
wind50 = []
cenlat50 = []
cenlon50 = []
size50 = []
ep50 = []
numb50 = []

# %%
#running for January 2019
test = ERAI_one_ellipse_calc(lev_list,contour_list,windlat,temp_lev,2019,1,31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50,)

# %%
years = [y for y in range(1959,1980,1)]
month = [11,12,1,2,3]

# %%
for i in range(len(years)):
    for j in range(len(month)):
        if years[i] == 1959 or years[i] == 1963 or years[i] == 1967 or years[i] == 1971 or years[i] == 1975 or years[i] == 1979:
            print(years[i])
            if month[j] == 11:
                print(month[j])
                calc = ERA5_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i],month[j],30,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)
                
                ephi_ratio10[i,:,0:30] = rat10[:]
                ephi_wind10[i,:,0:30] = wind10[:]
                ephi_cenlat10[i,:,0:30] = cenlat10[:]
                ephi_cenlon10[i,:,0:30] = cenlon10[:]
                ephi_size10[i,:,0:30] = size10[:]
                ephi10[i,:,0:30] = ep10[:]
                number10[i,0:30] = numb10[:]
                
                #ephi_ratio50[i,:,0:30] = rat50[:]
                #ephi_wind50[i,:,0:30] = wind50[:]
                #ephi_cenlat50[i,:,0:30] = cenlat50[:]
                #ephi_cenlon50[i,:,0:30] = cenlon50[:]
                #ephi_size50[i,:,0:30] = size50[:]
                #ephi50[i,:,0:30] = ep50[:]
                #number50[i,0:30] = numb50[:]
                
            if month[j] == 12:
                print(month[j])
                calc = ERA5_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i],month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,:,30:61] = rat10[:]
                ephi_wind10[i,:,30:61] = wind10[:]
                ephi_cenlat10[i,:,30:61] = cenlat10[:]
                ephi_cenlon10[i,:,30:61] = cenlon10[:]
                ephi_size10[i,:,30:61] = size10[:]
                ephi10[i,:,30:61] = ep10[:]
                number10[i,30:61] = numb10[:]
                
                #ephi_ratio50[i,:,30:61] = rat50[:]
                #ephi_wind50[i,:,30:61] = wind50[:]
                #ephi_cenlat50[i,:,30:61] = cenlat50[:]
                #ephi_cenlon50[i,:,30:61] = cenlon50[:]
                #ephi_size50[i,:,30:61] = size50[:]
                #ephi50[i,:,30:61] = ep50[:]
                #number50[i,30:61] = numb50[:]
            
            if month[j] == 1:
                print(month[j])
                calc = ERA5_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,:,61:92] = rat10[:]
                ephi_wind10[i,:,61:92] = wind10[:]
                ephi_cenlat10[i,:,61:92] = cenlat10[:]
                ephi_cenlon10[i,:,61:92] = cenlon10[:]
                ephi_size10[i,:,61:92] = size10[:]
                ephi10[i,:,61:92] = ep10[:]
                number10[i,61:92] = numb10[:]
                
                #ephi_ratio50[i,:,61:92] = rat50[:]
                #ephi_wind50[i,:,61:92] = wind50[:]
                #ephi_cenlat50[i,:,61:92 = cenlat50[:]
                #ephi_cenlon50[i,:,61:92] = cenlon50[:]
                #ephi_size50[i,:,61:92] = size50[:]
                #ephi50[i,:,61:92] = ep50[:]
                #number50[i,61:92] = numb50[:]
            
            if month[j] == 2:
                print(month[j])
                calc = ERA5_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],29,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,:,92:121] = rat10[:]
                ephi_wind10[i,:,92:121] = wind10[:]
                ephi_cenlat10[i,:,92:121] = cenlat10[:]
                ephi_cenlon10[i,:,92:121] = cenlon10[:]
                ephi_size10[i,:,92:121] = size10[:]
                ephi10[i,:,92:121] = ep10[:]
                number10[i,92:121] = numb10[:]
                
                #ephi_ratio50[i,:,92:121] = rat50[:]
                #ephi_wind50[i,:,92:121] = wind50[:]
                #ephi_cenlat50[i,:,92:121] = cenlat50[:]
                #ephi_cenlon50[i,:,92:121] = cenlon50[:]
                #ephi_size50[i,:,92:121] = size50[:]
                #ephi50[i,:,92:121] = ep50[:]
                #number50[i,92:121] = numb50[:]
            
            if month[j] == 3:
                print(month[j])
                calc = ERA5_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,:,121:] = rat10[:]
                ephi_wind10[i,:,121:] = wind10[:]
                ephi_cenlat10[i,:,121:] = cenlat10[:]
                ephi_cenlon10[i,:,121:] = cenlon10[:]
                ephi_size10[i,:,121:] = size10[:]
                ephi10[i,:,121:] = ep10[:]
                number10[i,121:] = numb10[:]
                
                #ephi_ratio50[i,:,121:] = rat50[:]
                #ephi_wind50[i,:,121:] = wind50[:]
                #ephi_cenlat50[i,:,121:] = cenlat50[:]
                #ephi_cenlon50[i,:,121:] = cenlon50[:]
                #ephi_size50[i,:,121:] = size50[:]
                #ephi50[i,:,121:] = ep50[:]
                #number50[i,121:] = numb50[:]
                
        else:
            print(years[i])
            if month[j] == 11:
                print(month[j])
                calc = ERA5_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i],month[j],30,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)
                
                ephi_ratio10[i,:,0:30] = rat10[:]
                ephi_wind10[i,:,0:30] = wind10[:]
                ephi_cenlat10[i,:,0:30] = cenlat10[:]
                ephi_cenlon10[i,:,0:30] = cenlon10[:]
                ephi_size10[i,:,0:30] = size10[:]
                ephi10[i,:,0:30] = ep10[:]
                number10[i,0:30] = numb10[:]
                
                #ephi_ratio50[i,:,0:30] = rat50[:]
                #ephi_wind50[i,:,0:30] = wind50[:]
                #ephi_cenlat50[i,:,0:30] = cenlat50[:]
                #ephi_cenlon50[i,:,0:30] = cenlon50[:]
                #ephi_size50[i,:,0:30] = size50[:]
                #ephi50[i,:,0:30] = ep50[:]
                #number50[i,0:30] = numb50[:]
                
            if month[j] == 12:
                print(month[j])
                calc = ERA5_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i],month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,:,30:61] = rat10[:]
                ephi_wind10[i,:,30:61] = wind10[:]
                ephi_cenlat10[i,:,30:61] = cenlat10[:]
                ephi_cenlon10[i,:,30:61] = cenlon10[:]
                ephi_size10[i,:,30:61] = size10[:]
                ephi10[i,:,30:61] = ep10[:]
                number10[i,30:61] = numb10[:]
                
                #ephi_ratio50[i,:,30:61] = rat50[:]
                #ephi_wind50[i,:,30:61] = wind50[:]
                #ephi_cenlat50[i,:,30:61] = cenlat50[:]
                #ephi_cenlon50[i,:,30:61] = cenlon50[:]
                #ephi_size50[i,:,30:61] = size50[:]
                #ephi50[i,:,30:61] = ep50[:]
                #number50[i,30:61] = numb50[:]
            
            if month[j] == 1:
                print(month[j])
                calc = ERA5_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,:,61:92] = rat10[:]
                ephi_wind10[i,:,61:92] = wind10[:]
                ephi_cenlat10[i,:,61:92] = cenlat10[:]
                ephi_cenlon10[i,:,61:92] = cenlon10[:]
                ephi_size10[i,:,61:92] = size10[:]
                ephi10[i,:,61:92] = ep10[:]
                number10[i,61:92] = numb10[:]
                
                #ephi_ratio50[i,:,61:92] = rat50[:]
                #ephi_wind50[i,:,61:92] = wind50[:]
                #ephi_cenlat50[i,:,61:92 = cenlat50[:]
                #ephi_cenlon50[i,:,61:92] = cenlon50[:]
                #ephi_size50[i,:,61:92] = size50[:]
                #ephi50[i,:,61:92] = ep50[:]
                #number50[i,61:92] = numb50[:]
            
            if month[j] == 2:
                print(month[j])
                calc = ERA5_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],28,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,:,92:120] = rat10[:]
                ephi_wind10[i,:,92:120] = wind10[:]
                ephi_cenlat10[i,:,92:120] = cenlat10[:]
                ephi_cenlon10[i,:,92:120] = cenlon10[:]
                ephi_size10[i,:,92:120] = size10[:]
                ephi10[i,:,92:120] = ep10[:]
                number10[i,92:120] = numb10[:]
                
                #ephi_ratio50[i,:,92:120] = rat50[:]
                #ephi_wind50[i,:,92:120] = wind50[:]
                #ephi_cenlat50[i,:,92:120] = cenlat50[:]
                #ephi_cenlon50[i,:,92:120] = cenlon50[:]
                #ephi_size50[i,:,92:120] = size50[:]
                #ephi50[i,:,92:120] = ep50[:]
                #number50[i,92:120] = numb50[:]
            
            if month[j] == 3:
                print(month[j])
                calc = ERA5_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,:,121:] = rat10[:]
                ephi_wind10[i,:,121:] = wind10[:]
                ephi_cenlat10[i,:,121:] = cenlat10[:]
                ephi_cenlon10[i,:,121:] = cenlon10[:]
                ephi_size10[i,:,121:] = size10[:]
                ephi10[i,:,121:] = ep10[:]
                number10[i,121:] = numb10[:]
                
                #ephi_ratio50[i,:,121:] = rat50[:]
                #ephi_wind50[i,:,121:] = wind50[:]
                #ephi_cenlat50[i,:,121:] = cenlat50[:]
                #ephi_cenlon50[i,:,121:] = cenlon50[:]
                #ephi_size50[i,:,121:] = size50[:]
                #ephi50[i,:,121:] = ep50[:]
                #number50[i,121:] = numb50[:]
# Out:
# 1959
# 11
# Opening ERA5 data 10 and contour level 30000
# Partitioning and averaging data.
# First, g data
# u data
# t data
# lat and lon
# level: 10
# date: [1401048. 1401072. 1401096. 1401120. 1401144. 1401168. 1401192. 1401216.
#  1401240. 1401264. 1401288. 1401312. 1401336. 1401360. 1401384. 1401408.
#  1401432. 1401456. 1401480. 1401504. 1401528. 1401552. 1401576. 1401600.
#  1401624. 1401648. 1401672. 1401696. 1401720. 1401744.]
# ##########################
# 1401048.0
# Date 00 UTC 01 Nov 1959
# range(18000, 33500, 250)
# in try
# Number of ellipses:  1
# in ellipse ...
# Number of ellipses:  1
# Diffs lat/lon:  0.01318755548078343 359.75
# It is True that the contour includes the pole
# Running ellipse diagnostic now
# Center of ellipse: 82.64384299771717 N 25.40279811549131 E
# Emetrics phi: -127.83380905308354
# right after savefig
# right after savefig
# date: [1401048. 1401072. 1401096. 1401120. 1401144. 1401168. 1401192. 1401216.
# ...

# %%
pickle.dump(ephi_ratio10, open("era5_ratio10_59.p", 'wb'))
pickle.dump(ephi_wind10, open("era5_wind10_59.p", 'wb')) 
pickle.dump(ephi_cenlat10, open("era5_cenlat10_59.p", 'wb'))
pickle.dump(ephi_cenlon10, open("era5_cenlon10_59.p", 'wb'))
pickle.dump(ephi_size10, open("era5_size10_59.p", 'wb'))
pickle.dump(ephi10, open("era5_ephi10_59.p", 'wb'))
pickle.dump(number10, open("era5_number10_59.p", 'wb'))

# %%
years = [y for y in range(1979,1991,1)]
month = [11,12,1,2,3]
## starting to establish the big ass loop for collecting data lol

# %%
for i in range(len(years)):
    for j in range(len(month)):
        if years[i] == 1979 or years[i] == 1983 or years[i] == 1987:
            print(years[i])
            if month[j] == 11:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i],month[j],30,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)
                
                ephi_ratio10[i,:,0:30] = rat10[:]
                ephi_wind10[i,:,0:30] = wind10[:]
                ephi_cenlat10[i,:,0:30] = cenlat10[:]
                ephi_cenlon10[i,:,0:30] = cenlon10[:]
                ephi_size10[i,:,0:30] = size10[:]
                ephi10[i,:,0:30] = ep10[:]
                number10[i,0:30] = numb10[:]
                
                #ephi_ratio50[i,:,0:30] = rat50[:]
                #ephi_wind50[i,:,0:30] = wind50[:]
                #ephi_cenlat50[i,:,0:30] = cenlat50[:]
                #ephi_cenlon50[i,:,0:30] = cenlon50[:]
                #ephi_size50[i,:,0:30] = size50[:]
                #ephi50[i,:,0:30] = ep50[:]
                #number50[i,0:30] = numb50[:]
                
            if month[j] == 12:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i],month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,:,30:61] = rat10[:]
                ephi_wind10[i,:,30:61] = wind10[:]
                ephi_cenlat10[i,:,30:61] = cenlat10[:]
                ephi_cenlon10[i,:,30:61] = cenlon10[:]
                ephi_size10[i,:,30:61] = size10[:]
                ephi10[i,:,30:61] = ep10[:]
                number10[i,30:61] = numb10[:]
                
                #ephi_ratio50[i,:,30:61] = rat50[:]
                #ephi_wind50[i,:,30:61] = wind50[:]
                #ephi_cenlat50[i,:,30:61] = cenlat50[:]
                #ephi_cenlon50[i,:,30:61] = cenlon50[:]
                #ephi_size50[i,:,30:61] = size50[:]
                #ephi50[i,:,30:61] = ep50[:]
                #number50[i,30:61] = numb50[:]
            
            if month[j] == 1:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,:,61:92] = rat10[:]
                ephi_wind10[i,:,61:92] = wind10[:]
                ephi_cenlat10[i,:,61:92] = cenlat10[:]
                ephi_cenlon10[i,:,61:92] = cenlon10[:]
                ephi_size10[i,:,61:92] = size10[:]
                ephi10[i,:,61:92] = ep10[:]
                number10[i,61:92] = numb10[:]
                
                #ephi_ratio50[i,:,61:92] = rat50[:]
                #ephi_wind50[i,:,61:92] = wind50[:]
                #ephi_cenlat50[i,:,61:92 = cenlat50[:]
                #ephi_cenlon50[i,:,61:92] = cenlon50[:]
                #ephi_size50[i,:,61:92] = size50[:]
                #ephi50[i,:,61:92] = ep50[:]
                #number50[i,61:92] = numb50[:]
            
            if month[j] == 2:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],29,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,:,92:121] = rat10[:]
                ephi_wind10[i,:,92:121] = wind10[:]
                ephi_cenlat10[i,:,92:121] = cenlat10[:]
                ephi_cenlon10[i,:,92:121] = cenlon10[:]
                ephi_size10[i,:,92:121] = size10[:]
                ephi10[i,:,92:121] = ep10[:]
                number10[i,92:121] = numb10[:]
                
                #ephi_ratio50[i,:,92:121] = rat50[:]
                #ephi_wind50[i,:,92:121] = wind50[:]
                #ephi_cenlat50[i,:,92:121] = cenlat50[:]
                #ephi_cenlon50[i,:,92:121] = cenlon50[:]
                #ephi_size50[i,:,92:121] = size50[:]
                #ephi50[i,:,92:121] = ep50[:]
                #number50[i,92:121] = numb50[:]
            
            if month[j] == 3:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,:,121:] = rat10[:]
                ephi_wind10[i,:,121:] = wind10[:]
                ephi_cenlat10[i,:,121:] = cenlat10[:]
                ephi_cenlon10[i,:,121:] = cenlon10[:]
                ephi_size10[i,:,121:] = size10[:]
                ephi10[i,:,121:] = ep10[:]
                number10[i,121:] = numb10[:]
                
                #ephi_ratio50[i,:,121:] = rat50[:]
                #ephi_wind50[i,:,121:] = wind50[:]
                #ephi_cenlat50[i,:,121:] = cenlat50[:]
                #ephi_cenlon50[i,:,121:] = cenlon50[:]
                #ephi_size50[i,:,121:] = size50[:]
                #ephi50[i,:,121:] = ep50[:]
                #number50[i,121:] = numb50[:]
                
        else:
            print(years[i])
            if month[j] == 11:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i],month[j],30,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)
                
                ephi_ratio10[i,:,0:30] = rat10[:]
                ephi_wind10[i,:,0:30] = wind10[:]
                ephi_cenlat10[i,:,0:30] = cenlat10[:]
                ephi_cenlon10[i,:,0:30] = cenlon10[:]
                ephi_size10[i,:,0:30] = size10[:]
                ephi10[i,:,0:30] = ep10[:]
                number10[i,0:30] = numb10[:]
                
                #ephi_ratio50[i,:,0:30] = rat50[:]
                #ephi_wind50[i,:,0:30] = wind50[:]
                #ephi_cenlat50[i,:,0:30] = cenlat50[:]
                #ephi_cenlon50[i,:,0:30] = cenlon50[:]
                #ephi_size50[i,:,0:30] = size50[:]
                #ephi50[i,:,0:30] = ep50[:]
                #number50[i,0:30] = numb50[:]
                
            if month[j] == 12:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i],month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,:,30:61] = rat10[:]
                ephi_wind10[i,:,30:61] = wind10[:]
                ephi_cenlat10[i,:,30:61] = cenlat10[:]
                ephi_cenlon10[i,:,30:61] = cenlon10[:]
                ephi_size10[i,:,30:61] = size10[:]
                ephi10[i,:,30:61] = ep10[:]
                number10[i,30:61] = numb10[:]
                
                #ephi_ratio50[i,:,30:61] = rat50[:]
                #ephi_wind50[i,:,30:61] = wind50[:]
                #ephi_cenlat50[i,:,30:61] = cenlat50[:]
                #ephi_cenlon50[i,:,30:61] = cenlon50[:]
                #ephi_size50[i,:,30:61] = size50[:]
                #ephi50[i,:,30:61] = ep50[:]
                #number50[i,30:61] = numb50[:]
            
            if month[j] == 1:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,:,61:92] = rat10[:]
                ephi_wind10[i,:,61:92] = wind10[:]
                ephi_cenlat10[i,:,61:92] = cenlat10[:]
                ephi_cenlon10[i,:,61:92] = cenlon10[:]
                ephi_size10[i,:,61:92] = size10[:]
                ephi10[i,:,61:92] = ep10[:]
                number10[i,61:92] = numb10[:]
                
                #ephi_ratio50[i,:,61:92] = rat50[:]
                #ephi_wind50[i,:,61:92] = wind50[:]
                #ephi_cenlat50[i,:,61:92 = cenlat50[:]
                #ephi_cenlon50[i,:,61:92] = cenlon50[:]
                #ephi_size50[i,:,61:92] = size50[:]
                #ephi50[i,:,61:92] = ep50[:]
                #number50[i,61:92] = numb50[:]
            
            if month[j] == 2:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],28,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,:,92:120] = rat10[:]
                ephi_wind10[i,:,92:120] = wind10[:]
                ephi_cenlat10[i,:,92:120] = cenlat10[:]
                ephi_cenlon10[i,:,92:120] = cenlon10[:]
                ephi_size10[i,:,92:120] = size10[:]
                ephi10[i,:,92:120] = ep10[:]
                number10[i,92:120] = numb10[:]
                
                #ephi_ratio50[i,:,92:120] = rat50[:]
                #ephi_wind50[i,:,92:120] = wind50[:]
                #ephi_cenlat50[i,:,92:120] = cenlat50[:]
                #ephi_cenlon50[i,:,92:120] = cenlon50[:]
                #ephi_size50[i,:,92:120] = size50[:]
                #ephi50[i,:,92:120] = ep50[:]
                #number50[i,92:120] = numb50[:]
            
            if month[j] == 3:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[i,:,121:] = rat10[:]
                ephi_wind10[i,:,121:] = wind10[:]
                ephi_cenlat10[i,:,121:] = cenlat10[:]
                ephi_cenlon10[i,:,121:] = cenlon10[:]
                ephi_size10[i,:,121:] = size10[:]
                ephi10[i,:,121:] = ep10[:]
                number10[i,121:] = numb10[:]
                
                #ephi_ratio50[i,:,121:] = rat50[:]
                #ephi_wind50[i,:,121:] = wind50[:]
                #ephi_cenlat50[i,:,121:] = cenlat50[:]
                #ephi_cenlon50[i,:,121:] = cenlon50[:]
                #ephi_size50[i,:,121:] = size50[:]
                #ephi50[i,:,121:] = ep50[:]
                #number50[i,121:] = numb50[:]

# %%
pickle.dump(ephi_ratio10, open("eraI_ratio10_79.p", 'wb'))
pickle.dump(ephi_wind10, open("eraI_wind10_79.p", 'wb')) 
pickle.dump(ephi_cenlat10, open("eraI_cenlat10_79.p", 'wb'))
pickle.dump(ephi_cenlon10, open("eraI_cenlon10_79.p", 'wb'))
pickle.dump(ephi_size10, open("eraI_size10_79.p", 'wb'))
pickle.dump(ephi10, open("eraI_ephi10_79.p", 'wb'))
pickle.dump(number10, open("eraI_number10_79.p", 'wb'))

# %%
index = [i for i in range(12,24,1)]
years = [i for i in range(1991,2003,1)]

# %%
for i in range(len(years)):
    for j in range(len(month)): 
        if years[i] == 1991 or years[i] == 1995 or years[i] == 1999 or years[i] == 2003:
            print(years[i])
            if month[j] == 11:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i],month[j],30,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)
                
                ephi_ratio10[index[i],:,0:30] = rat10[:]
                ephi_wind10[index[i],:,0:30] = wind10[:]
                ephi_cenlat10[index[i],:,0:30] = cenlat10[:]
                ephi_cenlon10[index[i],:,0:30] = cenlon10[:]
                ephi_size10[index[i],:,0:30] = size10[:]
                ephi10[index[i],:,0:30] = ep10[:]
                number10[index[i],0:30] = numb10[:]
                
                #ephi_ratio50[index[i],:,0:30] = rat50[:]
                #ephi_wind50[index[i],:,0:30] = wind50[:]
                #ephi_cenlat50[index[i],:,0:30] = cenlat50[:]
                #ephi_cenlon50[index[i],:,0:30] = cenlon50[:]
                #ephi_size50[index[i],:,0:30] = size50[:]
                #ephi50[index[i],:,0:30] = ep50[:]
                #number50[index[i],0:30] = numb50[:]
                
            if month[j] == 12:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i],month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[index[i],:,30:61] = rat10[:]
                ephi_wind10[index[i],:,30:61] = wind10[:]
                ephi_cenlat10[index[i],:,30:61] = cenlat10[:]
                ephi_cenlon10[index[i],:,30:61] = cenlon10[:]
                ephi_size10[index[i],:,30:61] = size10[:]
                ephi10[index[i],:,30:61] = ep10[:]
                number10[index[i],30:61] = numb10[:]
                
                #ephi_ratio50[index[i],:,30:61] = rat50[:]
                #ephi_wind50[index[i],:,30:61] = wind50[:]
                #ephi_cenlat50[index[i],:,30:61] = cenlat50[:]
                #ephi_cenlon50[index[i],:,30:61] = cenlon50[:]
                #ephi_size50[index[i],:,30:61] = size50[:]
                #ephi50[index[i],:,30:61] = ep50[:]
                #number50[index[i],30:61] = numb50[:]
            
            if month[j] == 1:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[index[i],:,61:92] = rat10[:]
                ephi_wind10[index[i],:,61:92] = wind10[:]
                ephi_cenlat10[index[i],:,61:92] = cenlat10[:]
                ephi_cenlon10[index[i],:,61:92] = cenlon10[:]
                ephi_size10[index[i],:,61:92] = size10[:]
                ephi10[index[i],:,61:92] = ep10[:]
                number10[index[i],61:92] = numb10[:]
                
                #ephi_ratio50[index[i],:,61:92] = rat50[:]
                #ephi_wind50[index[i],:,61:92] = wind50[:]
                #ephi_cenlat50[index[i],:,61:92 = cenlat50[:]
                #ephi_cenlon50[index[i],:,61:92] = cenlon50[:]
                #ephi_size50[index[i],:,61:92] = size50[:]
                #ephi50[index[i],:,61:92] = ep50[:]
                #number50[index[i],61:92] = numb50[:]
            
            if month[j] == 2:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],29,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[index[i],:,92:121] = rat10[:]
                ephi_wind10[index[i],:,92:121] = wind10[:]
                ephi_cenlat10[index[i],:,92:121] = cenlat10[:]
                ephi_cenlon10[index[i],:,92:121] = cenlon10[:]
                ephi_size10[index[i],:,92:121] = size10[:]
                ephi10[index[i],:,92:121] = ep10[:]
                number10[index[i],92:121] = numb10[:]
                
                #ephi_ratio50[index[i],:,92:121] = rat50[:]
                #ephi_wind50[index[i],:,92:121] = wind50[:]
                #ephi_cenlat50[index[i],:,92:121] = cenlat50[:]
                #ephi_cenlon50[index[i],:,92:121] = cenlon50[:]
                #ephi_size50[index[i],:,92:121] = size50[:]
                #ephi50[index[i],:,92:121] = ep50[:]
                #number50[index[i],92:121] = numb50[:]
            
            if month[j] == 3:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[index[i],:,121:] = rat10[:]
                ephi_wind10[index[i],:,121:] = wind10[:]
                ephi_cenlat10[index[i],:,121:] = cenlat10[:]
                ephi_cenlon10[index[i],:,121:] = cenlon10[:]
                ephi_size10[index[i],:,121:] = size10[:]
                ephi10[index[i],:,121:] = ep10[:]
                number10[index[i],121:] = numb10[:]
                
                #ephi_ratio50[index[i],:,121:] = rat50[:]
                #ephi_wind50[index[i],:,121:] = wind50[:]
                #ephi_cenlat50[index[i],:,121:] = cenlat50[:]
                #ephi_cenlon50[index[i],:,121:] = cenlon50[:]
                #ephi_size50[index[i],:,121:] = size50[:]
                #ephi50[index[i],:,121:] = ep50[:]
                #number50[index[i],121:] = numb50[:]
                
        else:
            print(years[i])
            if month[j] == 11:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i],month[j],30,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)
                
                ephi_ratio10[index[i],:,0:30] = rat10[:]
                ephi_wind10[index[i],:,0:30] = wind10[:]
                ephi_cenlat10[index[i],:,0:30] = cenlat10[:]
                ephi_cenlon10[index[i],:,0:30] = cenlon10[:]
                ephi_size10[index[i],:,0:30] = size10[:]
                ephi10[index[i],:,0:30] = ep10[:]
                number10[index[i],0:30] = numb10[:]
                
                #ephi_ratio50[index[i],:,0:30] = rat50[:]
                #ephi_wind50[index[i],:,0:30] = wind50[:]
                #ephi_cenlat50[index[i],:,0:30] = cenlat50[:]
                #ephi_cenlon50[index[i],:,0:30] = cenlon50[:]
                #ephi_size50[index[i],:,0:30] = size50[:]
                #ephi50[index[i],:,0:30] = ep50[:]
                #number50[index[i],0:30] = numb50[:]
                
            if month[j] == 12:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i],month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[index[i],:,30:61] = rat10[:]
                ephi_wind10[index[i],:,30:61] = wind10[:]
                ephi_cenlat10[index[i],:,30:61] = cenlat10[:]
                ephi_cenlon10[index[i],:,30:61] = cenlon10[:]
                ephi_size10[index[i],:,30:61] = size10[:]
                ephi10[index[i],:,30:61] = ep10[:]
                number10[index[i],30:61] = numb10[:]
                
                #ephi_ratio50[index[i],:,30:61] = rat50[:]
                #ephi_wind50[index[i],:,30:61] = wind50[:]
                #ephi_cenlat50[index[i],:,30:61] = cenlat50[:]
                #ephi_cenlon50[index[i],:,30:61] = cenlon50[:]
                #ephi_size50[index[i],:,30:61] = size50[:]
                #ephi50[index[i],:,30:61] = ep50[:]
                #number50[index[i],30:61] = numb50[:]
            
            if month[j] == 1:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[index[i],:,61:92] = rat10[:]
                ephi_wind10[index[i],:,61:92] = wind10[:]
                ephi_cenlat10[index[i],:,61:92] = cenlat10[:]
                ephi_cenlon10[index[i],:,61:92] = cenlon10[:]
                ephi_size10[index[i],:,61:92] = size10[:]
                ephi10[index[i],:,61:92] = ep10[:]
                number10[index[i],61:92] = numb10[:]
                
                #ephi_ratio50[index[i],:,61:92] = rat50[:]
                #ephi_wind50[index[i],:,61:92] = wind50[:]
                #ephi_cenlat50[index[i],:,61:92 = cenlat50[:]
                #ephi_cenlon50[index[i],:,61:92] = cenlon50[:]
                #ephi_size50[index[i],:,61:92] = size50[:]
                #ephi50[index[i],:,61:92] = ep50[:]
                #number50[index[i],61:92] = numb50[:]
            
            if month[j] == 2:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],28,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[index[i],:,92:120] = rat10[:]
                ephi_wind10[index[i],:,92:120] = wind10[:]
                ephi_cenlat10[index[i],:,92:120] = cenlat10[:]
                ephi_cenlon10[index[i],:,92:120] = cenlon10[:]
                ephi_size10[index[i],:,92:120] = size10[:]
                ephi10[index[i],:,92:120] = ep10[:]
                number10[index[i],92:120] = numb10[:]
                
                #ephi_ratio50[index[i],:,92:120] = rat50[:]
                #ephi_wind50[index[i],:,92:120] = wind50[:]
                #ephi_cenlat50[index[i],:,92:120] = cenlat50[:]
                #ephi_cenlon50[index[i],:,92:120] = cenlon50[:]
                #ephi_size50[index[i],:,92:120] = size50[:]
                #ephi50[index[i],:,92:120] = ep50[:]
                #number50[index[i],92:120] = numb50[:]
            
            if month[j] == 3:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[index[i],:,121:] = rat10[:]
                ephi_wind10[index[i],:,121:] = wind10[:]
                ephi_cenlat10[index[i],:,121:] = cenlat10[:]
                ephi_cenlon10[index[i],:,121:] = cenlon10[:]
                ephi_size10[index[i],:,121:] = size10[:]
                ephi10[index[i],:,121:] = ep10[:]
                number10[index[i],121:] = numb10[:]
                
                #ephi_ratio50[index[i],:,121:] = rat50[:]
                #ephi_wind50[index[i],:,121:] = wind50[:]
                #ephi_cenlat50[index[i],:,121:] = cenlat50[:]
                #ephi_cenlon50[index[i],:,121:] = cenlon50[:]
                #ephi_size50[index[i],:,121:] = size50[:]
                #ephi50[index[i],:,121:] = ep50[:]
                #number50[index[i],121:] = numb50[:]

# %%
pickle.dump(ephi_ratio10, open("eraI_ratio10_79.p", 'wb'))
pickle.dump(ephi_wind10, open("eraI_wind10_79.p", 'wb')) 
pickle.dump(ephi_cenlat10, open("eraI_cenlat10_79.p", 'wb'))
pickle.dump(ephi_cenlon10, open("eraI_cenlon10_79.p", 'wb'))
pickle.dump(ephi_size10, open("eraI_size10_79.p", 'wb'))
pickle.dump(ephi10, open("eraI_ephi10_79.p", 'wb'))
pickle.dump(number10, open("eraI_number10_79.p", 'wb'))

# %%
index = [i for i in range(24,40,1)]
years = [i for i in range(2003,2019,1)]

# %%
for i in range(len(years)):
    for j in range(len(month)):
        if years[i] == 2003 or years[i] == 2007 or years[i] == 2011 or years[i] == 2015 or years[i] == 2019:
            print(years[i])
            if month[j] == 11:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i],month[j],30,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)
                
                ephi_ratio10[index[i],:,0:30] = rat10[:]
                ephi_wind10[index[i],:,0:30] = wind10[:]
                ephi_cenlat10[index[i],:,0:30] = cenlat10[:]
                ephi_cenlon10[index[i],:,0:30] = cenlon10[:]
                ephi_size10[index[i],:,0:30] = size10[:]
                ephi10[index[i],:,0:30] = ep10[:]
                number10[index[i],0:30] = numb10[:]
                
                #ephi_ratio50[index[i],:,0:30] = rat50[:]
                #ephi_wind50[index[i],:,0:30] = wind50[:]
                #ephi_cenlat50[index[i],:,0:30] = cenlat50[:]
                #ephi_cenlon50[index[i],:,0:30] = cenlon50[:]
                #ephi_size50[index[i],:,0:30] = size50[:]
                #ephi50[index[i],:,0:30] = ep50[:]
                #number50[index[i],0:30] = numb50[:]
                
            if month[j] == 12:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i],month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[index[i],:,30:61] = rat10[:]
                ephi_wind10[index[i],:,30:61] = wind10[:]
                ephi_cenlat10[index[i],:,30:61] = cenlat10[:]
                ephi_cenlon10[index[i],:,30:61] = cenlon10[:]
                ephi_size10[index[i],:,30:61] = size10[:]
                ephi10[index[i],:,30:61] = ep10[:]
                number10[index[i],30:61] = numb10[:]
                
                #ephi_ratio50[index[i],:,30:61] = rat50[:]
                #ephi_wind50[index[i],:,30:61] = wind50[:]
                #ephi_cenlat50[index[i],:,30:61] = cenlat50[:]
                #ephi_cenlon50[index[i],:,30:61] = cenlon50[:]
                #ephi_size50[index[i],:,30:61] = size50[:]
                #ephi50[index[i],:,30:61] = ep50[:]
                #number50[index[i],30:61] = numb50[:]
            
            if month[j] == 1:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[index[i],:,61:92] = rat10[:]
                ephi_wind10[index[i],:,61:92] = wind10[:]
                ephi_cenlat10[index[i],:,61:92] = cenlat10[:]
                ephi_cenlon10[index[i],:,61:92] = cenlon10[:]
                ephi_size10[index[i],:,61:92] = size10[:]
                ephi10[index[i],:,61:92] = ep10[:]
                number10[index[i],61:92] = numb10[:]
                
                #ephi_ratio50[index[i],:,61:92] = rat50[:]
                #ephi_wind50[index[i],:,61:92] = wind50[:]
                #ephi_cenlat50[index[i],:,61:92 = cenlat50[:]
                #ephi_cenlon50[index[i],:,61:92] = cenlon50[:]
                #ephi_size50[index[i],:,61:92] = size50[:]
                #ephi50[index[i],:,61:92] = ep50[:]
                #number50[index[i],61:92] = numb50[:]
            
            if month[j] == 2:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],29,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[index[i],:,92:121] = rat10[:]
                ephi_wind10[index[i],:,92:121] = wind10[:]
                ephi_cenlat10[index[i],:,92:121] = cenlat10[:]
                ephi_cenlon10[index[i],:,92:121] = cenlon10[:]
                ephi_size10[index[i],:,92:121] = size10[:]
                ephi10[index[i],:,92:121] = ep10[:]
                number10[index[i],92:121] = numb10[:]
                
                #ephi_ratio50[index[i],:,92:121] = rat50[:]
                #ephi_wind50[index[i],:,92:121] = wind50[:]
                #ephi_cenlat50[index[i],:,92:121] = cenlat50[:]
                #ephi_cenlon50[index[i],:,92:121] = cenlon50[:]
                #ephi_size50[index[i],:,92:121] = size50[:]
                #ephi50[index[i],:,92:121] = ep50[:]
                #number50[index[i],92:121] = numb50[:]
            
            if month[j] == 3:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[index[i],:,121:] = rat10[:]
                ephi_wind10[index[i],:,121:] = wind10[:]
                ephi_cenlat10[index[i],:,121:] = cenlat10[:]
                ephi_cenlon10[index[i],:,121:] = cenlon10[:]
                ephi_size10[index[i],:,121:] = size10[:]
                ephi10[index[i],:,121:] = ep10[:]
                number10[index[i],121:] = numb10[:]
                
                #ephi_ratio50[index[i],:,121:] = rat50[:]
                #ephi_wind50[index[i],:,121:] = wind50[:]
                #ephi_cenlat50[index[i],:,121:] = cenlat50[:]
                #ephi_cenlon50[index[i],:,121:] = cenlon50[:]
                #ephi_size50[index[i],:,121:] = size50[:]
                #ephi50[index[i],:,121:] = ep50[:]
                #number50[index[i],121:] = numb50[:]
                
        else:
            print(years[i])
            if month[j] == 11:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i],month[j],30,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)
                
                ephi_ratio10[index[i],:,0:30] = rat10[:]
                ephi_wind10[index[i],:,0:30] = wind10[:]
                ephi_cenlat10[index[i],:,0:30] = cenlat10[:]
                ephi_cenlon10[index[i],:,0:30] = cenlon10[:]
                ephi_size10[index[i],:,0:30] = size10[:]
                ephi10[index[i],:,0:30] = ep10[:]
                number10[index[i],0:30] = numb10[:]
                
                #ephi_ratio50[index[i],:,0:30] = rat50[:]
                #ephi_wind50[index[i],:,0:30] = wind50[:]
                #ephi_cenlat50[index[i],:,0:30] = cenlat50[:]
                #ephi_cenlon50[index[i],:,0:30] = cenlon50[:]
                #ephi_size50[index[i],:,0:30] = size50[:]
                #ephi50[index[i],:,0:30] = ep50[:]
                #number50[index[i],0:30] = numb50[:]
                
            if month[j] == 12:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i],month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[index[i],:,30:61] = rat10[:]
                ephi_wind10[index[i],:,30:61] = wind10[:]
                ephi_cenlat10[index[i],:,30:61] = cenlat10[:]
                ephi_cenlon10[index[i],:,30:61] = cenlon10[:]
                ephi_size10[index[i],:,30:61] = size10[:]
                ephi10[index[i],:,30:61] = ep10[:]
                number10[index[i],30:61] = numb10[:]
                
                #ephi_ratio50[index[i],:,30:61] = rat50[:]
                #ephi_wind50[index[i],:,30:61] = wind50[:]
                #ephi_cenlat50[index[i],:,30:61] = cenlat50[:]
                #ephi_cenlon50[index[i],:,30:61] = cenlon50[:]
                #ephi_size50[index[i],:,30:61] = size50[:]
                #ephi50[index[i],:,30:61] = ep50[:]
                #number50[index[i],30:61] = numb50[:]
            
            if month[j] == 1:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[index[i],:,61:92] = rat10[:]
                ephi_wind10[index[i],:,61:92] = wind10[:]
                ephi_cenlat10[index[i],:,61:92] = cenlat10[:]
                ephi_cenlon10[index[i],:,61:92] = cenlon10[:]
                ephi_size10[index[i],:,61:92] = size10[:]
                ephi10[index[i],:,61:92] = ep10[:]
                number10[index[i],61:92] = numb10[:]
                
                #ephi_ratio50[index[i],:,61:92] = rat50[:]
                #ephi_wind50[index[i],:,61:92] = wind50[:]
                #ephi_cenlat50[index[i],:,61:92 = cenlat50[:]
                #ephi_cenlon50[index[i],:,61:92] = cenlon50[:]
                #ephi_size50[index[i],:,61:92] = size50[:]
                #ephi50[index[i],:,61:92] = ep50[:]
                #number50[index[i],61:92] = numb50[:]
            
            if month[j] == 2:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],28,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[index[i],:,92:120] = rat10[:]
                ephi_wind10[index[i],:,92:120] = wind10[:]
                ephi_cenlat10[index[i],:,92:120] = cenlat10[:]
                ephi_cenlon10[index[i],:,92:120] = cenlon10[:]
                ephi_size10[index[i],:,92:120] = size10[:]
                ephi10[index[i],:,92:120] = ep10[:]
                number10[index[i],92:120] = numb10[:]
                
                #ephi_ratio50[index[i],:,92:120] = rat50[:]
                #ephi_wind50[index[i],:,92:120] = wind50[:]
                #ephi_cenlat50[index[i],:,92:120] = cenlat50[:]
                #ephi_cenlon50[index[i],:,92:120] = cenlon50[:]
                #ephi_size50[index[i],:,92:120] = size50[:]
                #ephi50[index[i],:,92:120] = ep50[:]
                #number50[index[i],92:120] = numb50[:]
            
            if month[j] == 3:
                print(month[j])
                calc = ERAI_two_ellipse_calc(lev_list,contour_list,windlat,temp_lev,years[i]+1,month[j],31,
                       rat10,wind10,cenlat10,cenlon10,size10,ep10,numb10,
                       rat50,wind50,cenlat50,cenlon50,size50,ep50,numb50)

                ephi_ratio10[index[i],:,121:] = rat10[:]
                ephi_wind10[index[i],:,121:] = wind10[:]
                ephi_cenlat10[index[i],:,121:] = cenlat10[:]
                ephi_cenlon10[index[i],:,121:] = cenlon10[:]
                ephi_size10[index[i],:,121:] = size10[:]
                ephi10[index[i],:,121:] = ep10[:]
                number10[index[i],121:] = numb10[:]
                
                #ephi_ratio50[index[i],:,121:] = rat50[:]
                #ephi_wind50[index[i],:,121:] = wind50[:]
                #ephi_cenlat50[index[i],:,121:] = cenlat50[:]
                #ephi_cenlon50[index[i],:,121:] = cenlon50[:]
                #ephi_size50[index[i],:,121:] = size50[:]
                #ephi50[index[i],:,121:] = ep50[:]
                #number50[index[i],121:] = numb50[:]

# %%
ephi10[39]

# %%
pickle.dump(ephi_ratio10, open("eraI_ratio10_79.p", 'wb'))
pickle.dump(ephi_wind10, open("eraI_wind10_79.p", 'wb')) 
pickle.dump(ephi_cenlat10, open("eraI_cenlat10_79.p", 'wb'))
pickle.dump(ephi_cenlon10, open("eraI_cenlon10_79.p", 'wb'))
pickle.dump(ephi_size10, open("eraI_size10_79.p", 'wb'))
pickle.dump(ephi10, open("eraI_ephi10_79.p", 'wb'))
pickle.dump(number10, open("eraI_number10_79.p", 'wb'))

# %% [raw]
# pickle.dump(ephi_ratio50, open("era5_ratio50_79.p", 'wb'))
# pickle.dump(ephi_wind50, open("era5_wind50_79.p", 'wb'))
# pickle.dump(ephi_cenlat50, open("era5_cenlat50_79.p", 'wb'))
# pickle.dump(ephi_cenlon50, open("era5_cenlon50_79.p", 'wb'))
# pickle.dump(ephi_size50, open("era5_size50_79.p", 'wb'))
# pickle.dump(ephi50, open("era5_ephi50_79.p", 'wb'))

# %% [markdown]
# You may then include by pickling these matrices out. You can make this more efficient by creating a for-loop to run multiple years and months.
